# %%
# Cargamos las librerías
import requests

# %%
page = requests.get("https://www.bankbazaar.com/fuel/petrol-price-delhi.html")

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content)

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /loan.html
# /personal-loan.html
# /home-loan.html
# /car-loan.html
# /two-wheeler-loan.html
# /used-car-loan.html
# /education-loan.html
# None
# /credit-card.html
# /debit-card.html
# /investment.html
# /mutual-fund.html
# /fixed-deposit-rate.html
# /savings-account.html
# /gold-rate-india.html
# /silver-rate-india.html
# /recurring-deposit-rates.html
# /nps-signup.html
# javascript:void(0);
# /verifyOwnershipForm.html
# javascript:void(0)
# javascript:void(0)
# /credit-score.html?variant=slide&utm_source=bb&utm_medium=display&utm_campaign=HEADER
# #
# None
# /credit-card.html
# /hdfc-credit-card.html
# /sbi-credit-card.html
# /citibank-credit-card.html
# /indusind-credit-card.html
# /credit-card/top-10-credit-cards-in-india.html
# None
# /home-loan.html
# /home-loan/emi-calculator.html
# /home-loan-interest-rate.html
# /home-loan-eligibility.html
# /home-loan-balance-transfer.html
# /home-loan/pradhan-mantri-awas-yojana.html
# /sbi-home-loan.html
# /hdfc-home-loan.html
# None
# ...
